# %% [markdown]
# # Kafka Consumer Notebook

# %% [markdown]
# ## Prerequisites
#
# Ensure the following prerequisites are met before running this notebook:
#
# * **Kafka Setup**: Confirm that Kafka is set up and data is being produced into a Kafka topic. This should have been completed in the notebook **01 Kafka Getting Started - Produce Messages**.
#
# ## Validate Data using Consumer
#
# Follow these steps to consume and validate the data in your Kafka topic:
#
# 1. **Connect to Confluent Kafka**:
#    * Establish a connection to your Confluent Kafka environment. Ensure that you have the necessary configurations and credentials to connect successfully.
# 2. **Consume Data**:
#    * Utilize the relevant APIs to start consuming messages from the Kafka topic.
#    * You may want to write a script or use existing tools to consume a few messages as a test.
# 3. **Data Validation**:
#    * Verify the integrity and accuracy of the data consumed from the Kafka topic.
#    * Check for specific attributes or values in the messages to ensure they meet the expected criteria.
# 4. **Logging and Output**:
#    * Optionally, log the results of your validation or output them to a file or screen to review the consumed messages.
#
# ## Additional Notes
#
# * Remember to handle any errors or exceptions that may occur during the connection or consumption processes.
# * Ensure that your consumer script is configured to connect to the correct Kafka cluster and topic.
#
# ## Conclusion
# * Implementing through validation checks on data consumed from Kafka not only ensures data quality but also mitigates the risks associated with data corruption or misconfiguration. This notebook provides a systematic approach to verify and validate data integrity in real-time streaming applications

# %%
from confluent_kafka import Consumer, KafkaError

# %%
# Kafka and Confluent Cloud Configuration
kafka_bootstrap_servers = "pkc-n98pk.us-west-2.aws.confluent.cloud:9092"
kafka_topic = "orders_topic"
kafka_api_key = "GIITD77LNNPTLUPY"
kafka_api_secret = "cfltGr8vg7/QUyxTssw3J2azvM7LLVn7DuZ/lVr+XscdG5uY/X9mEp3g6v6fG80g"

# %%
# Consumer configuration
conf = {
    'bootstrap.servers': kafka_bootstrap_servers,
    'sasl.mechanisms': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': kafka_api_key,
    'sasl.password': kafka_api_secret,
    'group.id': 'user-consumer-group',
    'auto.offset.reset': 'latest'
}

# %%
# Create Consumer instance
consumer = Consumer(conf)
# Out:
# %6|1784221723.987|GETSUBSCRIPTIONS|rdkafka#consumer-1| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to 7E8dPsMCT4OU2i/6vaKaGQ

# %%
# Subscribe to topic
consumer.subscribe([kafka_topic])

# %%
# Read messages from Kafka
try:
    while True:
        msg = consumer.poll(1.0) # Timeout of 1 second
        
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                # End of partition event
                print(f"{msg.topic()} [{msg.partition()}] reached end at offset {msg.offset()}")
            elif msg.error():
                raise KafkaException(msg.error())
        else:
            # Proper message
            print(f"Received message: {msg.value().decode('utf-8')}")

except KeyboardInterrupt:
    pass
finally:
    # Close down consumer to commit final offsets.
    consumer.close()
# Out:
# Received message: {"order_id": "fef1aa9b-3d98-44a1-9504-9634a60dfc37", "customer_id": "39f401d4-ffd5-4ae2-9e9d-686ed8be243c", "product": "Mechanical Keyboard", "quantity": 3, "price": 774.51, "order_timestamp": "2026-07-16T14:30:12.582985+00:00"}
# Received message: {"order_id": "7c305117-8cab-4c0f-9f15-44628e44e82a", "customer_id": "f93d1005-70a4-451a-aa1a-f8b40c82605e", "product": "Noise Cancelling Headphones", "quantity": 2, "price": 1408.58, "order_timestamp": "2026-07-16T14:30:26.184864+00:00"}
# Received message: {"order_id": "1b7a22a8-7679-4911-8325-87869500665b", "customer_id": "1d6cb1c4-147d-4fc6-a838-df97d93229d4", "product": "Wireless Mouse", "quantity": 3, "price": 881.03, "order_timestamp": "2026-07-16T14:30:28.197092+00:00"}
# Received message: {"order_id": "89757e3b-afb1-47bc-a54e-2f25b73056b9", "customer_id": "4958d593-0566-42b5-8139-20076cbd05ef", "product": "4K Monitor", "quantity": 5, "price": 2115.34, "order_timestamp": "2026-07-16T14:30:08.541975+00:00"}
# Received message: {"order_id": "c3068662-2aa0-449b-9868-a55c71022d23", "customer_id": "9314849a-0f85-4c77-afa8-4d363dedb3c1", "product": "Smart Watch", "quantity": 1, "price": 1208.34, "order_timestamp": "2026-07-16T14:30:10.561499+00:00"}
# Received message: {"order_id": "7616ca48-3a81-49a5-8b44-158c925d80aa", "customer_id": "b500734c-962a-4bf6-8bf7-9076c1998e3c", "product": "USB-C Hub", "quantity": 3, "price": 179.07, "order_timestamp": "2026-07-16T14:30:11.572256+00:00"}
# Received message: {"order_id": "dcfeb85a-354c-457c-ad70-6ff1aa177a48", "customer_id": "e1d42429-5900-4d66-b9af-a0d7a2ef6089", "product": "RAM 32GB", "quantity": 5, "price": 1448.8, "order_timestamp": "2026-07-16T14:30:14.097940+00:00"}
# Received message: {"order_id": "43556829-ac97-4bb6-bedd-f280ee2eabeb", "customer_id": "ec120fd3-868f-4495-9558-576bfa87713b", "product": "Laptop Stand", "quantity": 3, "price": 1223.44, "order_timestamp": "2026-07-16T14:30:19.637449+00:00"}
# Received message: {"order_id": "30e1b126-7c51-47a1-9534-2ffa91ae2461", "customer_id": "77fcb67e-4b7d-41ea-a148-ba889f243acd", "product": "Smart Watch", "quantity": 5, "price": 962.89, "order_timestamp": "2026-07-16T14:30:20.644452+00:00"}
# Received message: {"order_id": "5ef197c2-7c59-4cc4-b789-5bc141b96b88", "customer_id": "bdefe73a-9619-4233-8dbe-897c8c824dd8", "product": "Mechanical Keyboard", "quantity": 2, "price": 1531.81, "order_timestamp": "2026-07-16T14:30:22.663408+00:00"}
# Received message: {"order_id": "7bc037dc-8e93-41cd-a474-6c1fd4d165f2", "customer_id": "1cc05810-4a2c-48a4-9a64-5c9f6870be47", "product": "Wireless Mouse", "quantity": 4, "price": 720.77, "order_timestamp": "2026-07-16T14:30:26.687852+00:00"}
# Received message: {"order_id": "59c45d07-b717-44f6-9ae1-fdaa2ee2abf7", "customer_id": "3df0163b-406f-4d48-8409-9af6722e123a", "product": "Laptop Stand", "quantity": 3, "price": 117.47, "order_timestamp": "2026-07-16T14:30:09.550215+00:00"}
# Received message: {"order_id": "5f90fe3a-015d-4774-997f-57092d030136", "customer_id": "bab30b41-1ed9-4a1d-90c8-4843c0a018a8", "product": "Laptop Stand", "quantity": 5, "price": 352.81, "order_timestamp": "2026-07-16T14:30:16.111657+00:00"}
# Received message: {"order_id": "6cc8407f-5ab7-4b97-983e-0d32a034d437", "customer_id": "5fbfefb4-1516-437b-a54b-7748a7204313", "product": "Laptop Stand", "quantity": 4, "price": 992.52, "order_timestamp": "2026-07-16T14:30:17.118987+00:00"}
# Received message: {"order_id": "2ea39491-7d14-467a-874a-5f38a59ea5a3", "customer_id": "b2f99720-dcf6-4ae9-b404-c0cb0b5bdf9d", "product": "Mechanical Keyboard", "quantity": 1, "price": 1445.99, "order_timestamp": "2026-07-16T14:30:17.624709+00:00"}
# Received message: {"order_id": "a8d4c502-2ec2-4fe2-9fa9-fc4642cd4435", "customer_id": "b53945da-e200-49dd-897b-12bb4aada62c", "product": "Noise Cancelling Headphones", "quantity": 2, "price": 2065.23, "order_timestamp": "2026-07-16T14:30:21.655813+00:00"}
# Received message: {"order_id": "a935b955-2a7f-4dd8-95d2-e44120a24321", "customer_id": "746f706d-fa42-4bdd-92fb-8dca63d6e972", "product": "Noise Cancelling Headphones", "quantity": 3, "price": 871.16, "order_timestamp": "2026-07-16T14:30:27.190193+00:00"}
# Received message: {"order_id": "d117579f-5bda-40e5-9d33-c4e3c2d61254", "customer_id": "3aaace7f-2e2a-46d1-8b8f-ed874921f550", "product": "Laptop Stand", "quantity": 3, "price": 1255.54, "order_timestamp": "2026-07-16T14:30:27.693054+00:00"}
# Received message: {"order_id": "2041c616-0819-4295-9b4e-c935ba846f48", "customer_id": "b6c40d84-3f41-4d81-ba52-dc4fcfa6afc9", "product": "Gaming Chair", "quantity": 4, "price": 1368.96, "order_timestamp": "2026-07-16T14:30:12.077653+00:00"}
# Received message: {"order_id": "5e2fa2db-1463-4646-a0be-8c6836889210", "customer_id": "c3c54cf9-96c1-486a-9368-ebd9c9d40320", "product": "Gaming Chair", "quantity": 4, "price": 1666.47, "order_timestamp": "2026-07-16T14:30:14.603329+00:00"}
# Received message: {"order_id": "25cfa009-442f-4e4c-a6b0-ed4d0ee4f3c0", "customer_id": "8cc75bfd-de8a-438a-a22b-6da4c1de98dd", "product": "RAM 32GB", "quantity": 2, "price": 1104.2, "order_timestamp": "2026-07-16T14:30:15.106152+00:00"}
# Received message: {"order_id": "867f3a98-0d4e-4f70-a758-b4c195e65ba1", "customer_id": "988abf9c-4675-43bb-8322-c56cf4896362", "product": "Noise Cancelling Headphones", "quantity": 3, "price": 2082.21, "order_timestamp": "2026-07-16T14:30:15.607169+00:00"}
# Received message: {"order_id": "9ea32c22-7b5d-4fe4-8836-32122fb34680", "customer_id": "56bd2122-66e8-4bb3-8320-90bc8e8c57e7", "product": "Webcam 1080p", "quantity": 3, "price": 236.21, "order_timestamp": "2026-07-16T14:30:16.615567+00:00"}
# Received message: {"order_id": "5856ee23-4a8c-4e5a-83a9-66c57c23adbb", "customer_id": "eee3153d-a45e-4443-b0d6-3aaab56af5c5", "product": "USB-C Hub", "quantity": 5, "price": 1260.94, "order_timestamp": "2026-07-16T14:30:18.125980+00:00"}
# Received message: {"order_id": "a4d595f5-9bb7-44ec-9186-d63b4fd70f28", "customer_id": "d52c5ed5-efcd-4c82-8dc5-7fe1741cac08", "product": "Gaming Chair", "quantity": 4, "price": 1949.65, "order_timestamp": "2026-07-16T14:30:18.630862+00:00"}
# Received message: {"order_id": "51afd5bd-9be1-4054-8e37-826d8483cfae", "customer_id": "787dedbd-47cc-468a-b02f-5c629c4d98d2", "product": "SSD 1TB", "quantity": 5, "price": 452.33, "order_timestamp": "2026-07-16T14:30:21.150204+00:00"}
# Received message: {"order_id": "66187f79-fafa-4b2e-9ea2-f886f90d3d97", "customer_id": "40918327-2290-45b9-a8be-deac667ac545", "product": "Smart Watch", "quantity": 2, "price": 1742.05, "order_timestamp": "2026-07-16T14:30:23.668168+00:00"}
# Received message: {"order_id": "d5fcc797-5653-4d20-ac8a-f6b5094da0d3", "customer_id": "a43f9149-5de9-470d-b621-c17efe452bd2", "product": "SSD 1TB", "quantity": 5, "price": 37.75, "order_timestamp": "2026-07-16T14:30:25.679080+00:00"}
# Received message: {"order_id": "435381a1-86a8-4c09-b8cf-5b8b8f792674", "customer_id": "eb7e093b-fa21-4414-a8b2-a5eb0c36e859", "product": "USB-C Hub", "quantity": 4, "price": 38.08, "order_timestamp": "2026-07-16T14:30:08.040794+00:00"}
# Received message: {"order_id": "a6d1bf7f-8e91-4912-b840-377ce1942559", "customer_id": "0f21559e-5c63-4aab-a62d-531a7e267a6c", "product": "Laptop Stand", "quantity": 2, "price": 1203.38, "order_timestamp": "2026-07-16T14:30:13.089054+00:00"}
# Received message: {"order_id": "e69ed3af-c7c5-40f6-a2e6-2d528873e113", "customer_id": "197af922-e591-4670-8fe1-5d5057c73dfe", "product": "Wireless Mouse", "quantity": 5, "price": 2359.72, "order_timestamp": "2026-07-16T14:30:13.593988+00:00"}
# Received message: {"order_id": "0db62029-6a12-47b0-ba2b-f959c3997de9", "customer_id": "c799adcc-f775-438b-a962-ea75fbf75fce", "product": "Webcam 1080p", "quantity": 4, "price": 1364.89, "order_timestamp": "2026-07-16T14:30:20.142380+00:00"}
# Received message: {"order_id": "a5d874d4-4910-46de-9469-73ed2d706123", "customer_id": "d2b8a598-43d0-4481-ae4c-c9aaf3890155", "product": "Laptop Stand", "quantity": 4, "price": 705.49, "order_timestamp": "2026-07-16T14:30:23.166876+00:00"}
# Received message: {"order_id": "714425fe-2a55-4a66-bcff-d83f163e60ce", "customer_id": "c91335c2-c9aa-432f-81ad-ac1a65f5a556", "product": "Laptop Stand", "quantity": 3, "price": 1794.16, "order_timestamp": "2026-07-16T14:30:28.697909+00:00"}
# Received message: {"order_id": "ec37d83d-0bf0-480b-b903-e541f9cf9eda", "customer_id": "ca1d162f-3265-427b-8720-f1a111d7114c", "product": "Webcam 1080p", "quantity": 2, "price": 108.18, "order_timestamp": "2026-07-16T14:30:09.044516+00:00"}
# Received message: {"order_id": "7abe786c-e5a7-4f0b-a393-2eb933f27b80", "customer_id": "d4666870-3ed0-4051-a764-aa08179b43f1", "product": "Laptop Stand", "quantity": 4, "price": 1059.22, "order_timestamp": "2026-07-16T14:30:10.055768+00:00"}
# Received message: {"order_id": "66d8faef-33d7-4ff9-96c8-e53012a211aa", "customer_id": "55f8bd68-686d-484c-b494-d56dcdc3e1bf", "product": "USB-C Hub", "quantity": 3, "price": 1031.0, "order_timestamp": "2026-07-16T14:30:11.067201+00:00"}
# Received message: {"order_id": "3fa64709-d0b6-4def-9a49-834c2c3e21cc", "customer_id": "e22eea0c-9b75-49bd-9518-d2c5a280efc3", "product": "Wireless Mouse", "quantity": 3, "price": 2419.57, "order_timestamp": "2026-07-16T14:30:19.131554+00:00"}
# Received message: {"order_id": "552b45db-b6c4-4489-a9cc-8fb8ddc9565f", "customer_id": "85e810a0-6cae-4cf9-94a4-783acdafd9d9", "product": "Laptop Stand", "quantity": 1, "price": 1064.7, "order_timestamp": "2026-07-16T14:30:22.157924+00:00"}
# Received message: {"order_id": "9d3ee845-a827-4a0e-8255-c471dfa2cd47", "customer_id": "2f004125-3715-4983-b21e-89d38f68f73c", "product": "Mechanical Keyboard", "quantity": 4, "price": 358.98, "order_timestamp": "2026-07-16T14:30:24.173145+00:00"}
# Received message: {"order_id": "bf0690fc-845e-4a14-adbf-659d7ae6cff5", "customer_id": "9699f161-a047-4420-b875-b24b2f38f2df", "product": "4K Monitor", "quantity": 4, "price": 2398.84, "order_timestamp": "2026-07-16T14:30:24.676402+00:00"}
# Received message: {"order_id": "eba520ad-f562-45bb-96d2-b2deef7cec34", "customer_id": "cc762e35-3eab-4f9d-9882-64b388fc7f74", "product": "Mechanical Keyboard", "quantity": 5, "price": 1154.56, "order_timestamp": "2026-07-16T14:30:25.178457+00:00"}
